# %%
# Program 1: Mobile Recharge Validation System

def validate_recharge(amount):
    valid_plans = [199, 299, 399, 599]
    
    if amount < 50:
        return "Recharge amount must be at least ₹50."
    elif amount not in valid_plans:
        return "Invalid plan selected."
    else:
        return "Recharge Successful!"

while True:
    amount = int(input("Enter recharge amount: "))
    result = validate_recharge(amount)
    print(result)
    
    if result == "Recharge Successful!":
        break
    else:
        print("Please try again.\n")
# Out:
# Invalid plan selected.
# Please try again.
#
# Recharge Successful!

# %%
# Program 2: Inventory Reorder Alert System

def check_inventory(products):
    for product, stock in products.items():
        if stock < 15:
            print(product, "→ Reorder Alert")
        else:
            print(product, "→ Stock OK")

inventory = {
    "Rice": 20,
    "Wheat": 10,
    "Sugar": 5,
    "Oil": 25
}

check_inventory(inventory)
# Out:
# Rice → Stock OK
# Wheat → Reorder Alert
# Sugar → Reorder Alert
# Oil → Stock OK

# %%
# Program 3: Student Result Processing System

def student_result(marks):
    total = 0
    for mark in marks:
        total += mark
    
    average = total / len(marks)
    print("Average Marks:", average)
    
    if average >= 50:
        return "Pass"
    else:
        return "Fail"

marks_list = [60, 70, 45, 55]
result = student_result(marks_list)
print("Result:", result)
# Out:
# Average Marks: 57.5
# Result: Pass

# %%
# Program 4: Cab Fare Estimator with Retry Option

def calculate_fare(distance, peak):
    base_fare = 50
    fare = base_fare + (12 * distance)
    
    if peak == "yes":
        fare += fare * 0.25
    
    return fare

while True:
    distance = float(input("Enter distance in km: "))
    peak = input("Is it peak hour? (yes/no): ").lower()
    
    total_fare = calculate_fare(distance, peak)
    print("Total Fare: ₹", total_fare)
    
    retry = input("Do you want to calculate again? (yes/no): ").lower()
    if retry != "yes":
        break
# Out:
# Total Fare: ₹ 152.5

# %%
# Program 5: Employee Attendance Eligibility Checker

def check_eligibility(attendance_list):
    present_days = 0
    
    for day in attendance_list:
        if day == "P":
            present_days += 1
    
    percentage = (present_days / len(attendance_list)) * 100
    print("Attendance Percentage:", percentage)
    
    if percentage >= 75:
        return "Eligible"
    else:
        return "Not Eligible"

attendance = ["P", "P", "A", "P", "P", "A", "P"]
result = check_eligibility(attendance)
print("Status:", result)
# Out:
# Attendance Percentage: 71.42857142857143
# Status: Not Eligible
